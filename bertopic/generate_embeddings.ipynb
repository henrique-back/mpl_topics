# %%
import numpy as np
import pandas as pd

# Set embedding model
from sentence_transformers import SentenceTransformer
sentence_model = SentenceTransformer("allenai-specter")

# Prepare the data
data = pd.read_csv(r'..\get_data\alldata.csv')

#Create abstract dataframe (docs) and save (change path to suit your case)
docs = data['Abstract']
docs = docs.tolist()

# Prepare embeddings and save (this saves a lot of time in the future)
embeddings = sentence_model.encode(docs, show_progress_bar=True)
np.save(r'..\bertopic\preprocessed_data\embeddings.csv.npy', embeddings)
print(embeddings.shape)
# Out:
# d:\Documentos\Projects\mpl_topics\mpl_topics_2025\venv\lib\site-packages\sentence_transformers\cross_encoder\CrossEncoder.py:11: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm, trange
# Batches:   0%|          | 0/388 [00:00<?, ?it/s]
# (12398, 768)

# %%
# Visualize a heatmap of the embeddings. This is done to get a sense of the dimensions and values of the embedded data

import matplotlib.pyplot as plt

# Set the figure size
plt.figure(figsize=(20, 16))

# Plot the heatmap
plt.imshow(embeddings)

# Adjust the aspect ratio of the plot
plt.gca().set_aspect('auto')

# Add a colorbar to the right
plt.colorbar()

# Show the plot
plt.show()
